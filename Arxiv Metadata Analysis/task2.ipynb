# %% [markdown]
# <a href="https://colab.research.google.com/github/DanB1421/DATA601/blob/main/task2.%20ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# In this task, the CSV files for each primary category of interest (cs.AI, cs.LG, cs.CC, and cs.AR) created in Task 1 are read into pandas dataframes. The first 5 entries of each dataframe are then displayed.

# %%
df1_final = pd.read_csv('/content/df1_final.csv', index_col=0) # reads the cs.AI CSV from Task 1 and treats the first column as an index
df1_final.head() # displays the first 5 rows of the dataframe
# Out:
#                                                title  \
# 0  AI Buzzwords Explained: Multi-Agent Path Findi...
# 1  A Tutorial on Modular Ontology Modeling with O...
# 2  AAAI FSS-18: Artificial Intelligence in Govern...
# 3                            The Book of Why: Review
# 4       Self-Learned Formula Synthesis in Set Theory
#
#                                          authors  \
# 0                     ['Hang Ma', 'Sven Koenig']
# 1          ['Pascal Hitzler', 'Adila Krisnadhi']
# 2  ['Frank Stein', 'Alun Preece', 'Mihai Boicu']
# 3                          ['Joseph Y. Halpern']
# 4         ['Chad E. Brown', 'Thibault Gauthier']
#
#                                              summary  \
# 0  Explanation of the hot topic "multi-agent path...
# 1  We provide a detailed example for modular onto...
# 2  Proceedings of the AAAI Fall Symposium on Arti...
# 3  This is a review of "The Book of Why", by Jude...
# 4  A reinforcement learning algorithm accomplishe...
#
# ...

# %%
df2_final = pd.read_csv('/content/df2_final.csv', index_col=0) # reads the cs.LG CSV from Task 1 and treats the first column as an index
df2_final.head() # displays the first 5 rows of the dataframe
# Out:
#                                                title  \
# 0              A Note on Kaldi's PLDA Implementation
# 1  Attack RMSE Leaderboard: An Introduction and C...
# 2  Exponential Convergence of the Deep Neural Net...
# 3  $α$-Approximation Density-based Clustering of ...
# 4   A conjugate prior for the Dirichlet distribution
#
#                         authors  \
# 0                   ['Ke Ding']
# 1                  ['Cong Xie']
# 2  ['Weinan E', 'Qingcan Wang']
# 3              ['Zhilin Zhang']
# 4        ['Jean-Marc Andreoli']
#
#                                              summary  \
# 0  Some explanations to Kaldi's PLDA implementati...
# 1  In this manuscript, we briefly introduce sever...
# 2  We prove that for analytic functions in low di...
# 3  This submission has been removed by arXiv admi...
# 4  This note investigates a conjugate class for t...
#
#                                              comment journal_ref  doi  \
# ...

# %%
df3_final = pd.read_csv('/content/df3_final.csv', index_col=0) # reads the cs.CC CSV from Task 1 and treats the first column as an index
df3_final.head() # displays the first 5 rows of the dataframe
# Out:
#                                                title  \
# 0  Complexity of Domination in Triangulated Plane...
# 1  2-CLUB is NP-hard for distance to 2-club clust...
# 2                       LIKE Patterns and Complexity
# 3  A polynomial time approximation schema for max...
# 4  A Simpler NP-Hardness Proof for Familial Graph...
#
#                                              authors  \
# 0                              ['Dömötör Pálvölgyi']
# 1                                ['Mithilesh Kumar']
# 2                                ['Holger Petersen']
# 3                           ['Vangelis Th. Paschos']
# 4  ['Ammar Ahmed', 'Zohair Raza Hassan', 'Mudassi...
#
#                                              summary comment journal_ref  doi  \
# 0  We prove that for a triangulated plane graph i...     NaN         NaN  NaN
# 1  We show that 2-CLUB is NP-hard for distance to...     NaN         NaN  NaN
# 2  We investigate the expressive power and comple...     NaN         NaN  NaN
# ...

# %%
df4_final = pd.read_csv('/content/df4_final.csv', index_col=0) # reads the cs.AR CSV from Task 1 and treats the first column as an index
df4_final.head() # displays the first 5 rows of the dataframe
# Out:
#                                                title  \
# 0   45-year CPU evolution: one law and two equations
# 1  A Compiler Infrastructure for FPGA and ASIC De...
# 2  A high-performance MEMRISTOR-based Smith-Water...
# 3  Hardware Architecture of Wireless Power Transf...
# 4  The Effect of Temperature on Amdahl Law in 3D ...
#
#                                              authors  \
# 0                                ['Daniel Etiemble']
# 1                                     ['John Demme']
# 2  ['Mahdi Taheri', 'Hamed Zandevakili', 'Ali Mah...
# 3                              ['Yu Luo', 'Lina Pu']
# 4     ['Leonid Yavits', 'Amir Morad', 'Ran Ginosar']
#
#                                              summary comment  \
# 0  Moore's law and two equations allow to explain...     NaN
# 1  This whitepaper proposes a unified framework f...     NaN
# 2  This paper aims to present a new re-configurat...     NaN
# 3  In this work, we provide an overview of the ha...     NaN
# ...
